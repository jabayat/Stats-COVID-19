# %%
import pandas as pd
import seaborn as sns
from DataHubIo import Dataset

# %%
data = Dataset()

# %%
country = 'DEU'

# %%
data.plot_country_cases(country)

# %%
data.plot_country_daily_cases(country)

# %%
countries = ['ITA', 'USA', 'CHE', 'DEU', 'FRA', 'GBR', 'ESP']

# %%
data.compare_countries_confirmed(countries)

# %%
data.compare_countries_active(countries)

# %%
data.compare_countries_recovered(countries)

# %%
data.compare_countries_deaths(countries)
